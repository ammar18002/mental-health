# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv('/Users/abdul/Downloads/mental-health/playground-series-s4e11/train_data_cleaned.csv')
test_data = pd.read_csv('/Users/abdul/Downloads/mental-health/playground-series-s4e11/test_data_cleaned.csv')

# %%
train_data.head(3)
# Out:
#    id      Name  Gender   Age           City Working Professional or Student  \
# 0   0  aaradhya  female  49.0       ludhiana            working professional
# 1   1     vivan    male  26.0       varanasi            working professional
# 2   2    yuvraj    male  33.0  visakhapatnam                         student
#
#   Profession  Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0       chef                NaN            5.0   NaN                 NaN
# 1    teacher                NaN            4.0   NaN                 NaN
# 2        NaN                5.0            NaN  8.97                 2.0
#
#    Job Satisfaction     Sleep Duration Dietary Habits   Degree  \
# 0               2.0  more than 8 hours        healthy      BHM
# 1               3.0  less than 5 hours      unhealthy      LLB
# 2               NaN          5-6 hours        healthy  B.Pharm
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# ...

# %%
# from autogluon.tabular import TabularDataset, TabularPredictor

# train = TabularDataset(train_data)
# test = TabularDataset(test_data)

# label = 'Depression'

# time_limit = 300

# predictor = TabularPredictor(label=label).fit(
#     train,
#     time_limit=time_limit,
#     presets='interpretable',     # <—— prevents AutoGluon from loading heavy models
#     hyperparameters={
#         'GBM': {},   # LightGBM
#         'RF': {},    # RandomForest
#         'XT': {},    # ExtraTrees
#         'KNN': {}    # K-Nearest Neighbors
#     },
#     ag_args_fit={'num_cpus': 2}   # reduce CPU load → reduces RAM usage on Mac
# )
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20251130_172132"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 24.6.0: Wed Oct 15 21:12:21 PDT 2025; root:xnu-11417.140.69.703.14~1/RELEASE_X86_64
# CPU Count:          12
# Memory Avail:       4.63 GB / 16.00 GB (28.9%)
# Disk Space Avail:   175.84 GB / 465.63 GB (37.8%)
# ...
# Presets specified: ['interpretable']
# Beginning AutoGluon training ... Time limit = 300s
# AutoGluon will save models to "/Users/abdul/mental-health/AutogluonModels/ag-20251130_172132"
# Train Data Rows:    140700
# Train Data Columns: 19
# Label Column:       Depression
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [np.int64(0), np.int64(1)]
# ...

# %%
from autogluon.tabular import TabularPredictor
predictor = TabularPredictor.load("AutogluonModels/ag-20251130_172132") #This is a KNN model for prediction

preds = predictor.predict(test_data)
preds.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: Depression, dtype: int64

# %%
preds.shape
# Out:
# (93800,)

# %%
# Build submission
submission = pd.DataFrame({
    "id": test_data["id"],
    "Depression": preds
})

# Save final CSV
submission.to_csv("submission_knn.csv", index=False)

submission.head()
# Out:
#        id  Depression
# 0  140700           0
# 1  140701           0
# 2  140702           0
# 3  140703           1
# 4  140704           0
